# %%
# !pip install pymysql

# %%
#python -m pip install --upgrade 'sqlalchemy<2.0'
from sqlalchemy import create_engine, text as sql_text
import pymysql
import pandas as pd

# %%
# Para saber o IP do Colab
# !curl ipecho.net/plain

# %%
#Estrutura 'mysql+pymysql://user:password@ip/schema'
#db_connection = 'mysql+pymysql://root:jef123*@34.123.106.29/ime'
db_connection = 'mysql+pymysql://root:jef123*@localhost/ime'
#conn = create_engine(db_connection)
engine = create_engine(db_connection)
conn = engine.connect()

# %%
#pd.read_sql ('show databases',conn)
query = sql_text('show databases')
pd.read_sql(query,conn)
# Out:
#              Database
# 0                 ime
# 1  information_schema
# 2               mysql
# 3           newschema
# 4  performance_schema
# 5                 sys

# %%
pd.read_sql ("""SELECT * FROM information_schema.tables where table_schema = 'ime'""",conn)
# Out:
#    TABLE_CATALOG TABLE_SCHEMA                            TABLE_NAME  \
# 0            def          ime                             __lex_vad
# 1            def          ime                              accounts
# 2            def          ime                     content_polluters
# 3            def          ime          content_polluters_followings
# 4            def          ime                content_polluters_full
# 5            def          ime  content_polluters_semcolestatisticas
# 6            def          ime              content_polluters_tweets
# 7            def          ime     content_polluters_tweets_original
# 8            def          ime      content_polluters_tweets_parcial
# 9            def          ime                      espaco_emocional
# 10           def          ime                 espaco_emocional_tang
# 11           def          ime                  espaco_emocional_vad
# 12           def          ime          espaco_emocional_vad_anew_br
# 13           def          ime                           labelednews
# 14           def          ime                      legitimate_users
# 15           def          ime           legitimate_users_followings
# 16           def          ime   legitimate_users_semcolestatisticas
# 17           def          ime               legitimate_users_tweets
# 18           def          ime      legitimate_users_tweets_original
# 19           def          ime                             news_fake
# 20           def          ime                          news_notfake
# 21           def          ime                   tweetsoflabelednews
# 22           def          ime                     users_from_setgen
# 23           def          ime                           vocabulario
#
#     TABLE_TYPE  ENGINE  VERSION ROW_FORMAT  TABLE_ROWS  AVG_ROW_LENGTH  \
# 0   BASE TABLE  InnoDB       10    Dynamic           0               0
# 1   BASE TABLE  InnoDB       10    Dynamic        4210            1871
# 2   BASE TABLE  InnoDB       10    Dynamic        1500            1758
# 3   BASE TABLE  InnoDB       10    Dynamic       20635            1145
# 4   BASE TABLE  InnoDB       10    Dynamic       20383            1520
# 5   BASE TABLE  InnoDB       10    Dynamic        1634             160
# 6   BASE TABLE  InnoDB       10    Dynamic      203626             296
# 7   BASE TABLE  InnoDB       10    Dynamic      232207             675
# 8   BASE TABLE  InnoDB       10    Dynamic      232564             309
# 9   BASE TABLE  InnoDB       10    Dynamic       13692             345
# 10  BASE TABLE  InnoDB       10    Dynamic      134872             260
# 11  BASE TABLE  InnoDB       10    Dynamic       13705             345
# 12  BASE TABLE  InnoDB       10    Dynamic        1045              94
# 13  BASE TABLE  InnoDB       10    Dynamic        2924             902
# 14  BASE TABLE  InnoDB       10    Dynamic       17530            1648
# 15  BASE TABLE  InnoDB       10    Dynamic       18272            1064
# 16  BASE TABLE  InnoDB       10    Dynamic       19253             191
# 17  BASE TABLE  InnoDB       10    Dynamic      443388             216
# 18  BASE TABLE  InnoDB       10    Dynamic      420450             562
# 19  BASE TABLE  InnoDB       10    Dynamic        1915            3020
# 20  BASE TABLE  InnoDB       10    Dynamic         267            1411
# 21  BASE TABLE  InnoDB       10    Dynamic      206806             429
# 22  BASE TABLE  InnoDB       10    Dynamic      100360            1763
# 23  BASE TABLE  InnoDB       10    Dynamic       22145              71
#
#     DATA_LENGTH  ...  INDEX_LENGTH  DATA_FREE  AUTO_INCREMENT  \
# 0         16384  ...         16384          0             NaN
# 1       7880704  ...         81920    4194304             NaN
# 2       2637824  ...         16384          0             NaN
# 3      23642112  ...        245760          0             NaN
# 4      30998528  ...        245760          0             NaN
# 5        262144  ...         16384          0             NaN
# 6      60358656  ...             0          0             NaN
# 7     156909568  ...             0          0             NaN
# 8      71892992  ...             0          0             NaN
# 9       4734976  ...        294912          0             NaN
# 10     35192832  ...             0          0        136858.0
# 11      4734976  ...        294912    4194304             NaN
# 12        98304  ...         49152          0          1046.0
# 13      2637824  ...             0          0             NaN
# 14     28901376  ...        212992          0             NaN
# 15     19447808  ...             0          0             NaN
# 16      3686400  ...        212992          0             NaN
# 17     96043008  ...             0          0             NaN
# 18    236683264  ...             0          0             NaN
# 19      5783552  ...             0          0             NaN
# 20       376832  ...             0          0             NaN
# 21     88850432  ...             0    4194304             NaN
# 22    176996352  ...       2637824          0             NaN
# 23      1589248  ...             0          0             NaN
#
#            CREATE_TIME UPDATE_TIME CHECK_TIME     TABLE_COLLATION CHECKSUM  \
# 0  2023-04-19 08:30:56        None       None  utf8mb4_0900_ai_ci     None
# 1  2023-04-19 08:28:38        None       None   latin1_swedish_ci     None
# 2  2023-04-19 08:28:43        None       None   latin1_swedish_ci     None
# 3  2023-04-19 08:28:44        None       None   latin1_swedish_ci     None
# 4  2023-04-19 08:28:47        None       None   latin1_swedish_ci     None
# 5  2023-04-19 08:28:57        None       None   latin1_swedish_ci     None
# 6  2023-04-19 08:28:57        None       None   latin1_swedish_ci     None
# 7  2023-04-19 08:29:06        None       None  utf8mb4_general_ci     None
# 8  2023-04-19 08:29:33        None       None   latin1_swedish_ci     None
# 9  2023-04-19 08:29:42        None       None   latin1_swedish_ci     None
# 10 2023-04-19 08:29:44        None       None  utf8mb4_0900_ai_ci     None
# 11 2023-04-19 08:29:51        None       None  utf8mb4_0900_ai_ci     None
# 12 2023-09-18 00:18:24        None       None   latin1_swedish_ci     None
# 13 2023-08-10 22:39:29        None       None  utf8mb4_0900_ai_ci     None
# 14 2023-04-19 08:29:52        None       None   latin1_swedish_ci     None
# 15 2023-04-19 08:29:58        None       None   latin1_swedish_ci     None
# 16 2023-04-19 08:30:00        None       None   latin1_swedish_ci     None
# 17 2023-04-19 08:30:01        None       None   latin1_swedish_ci     None
# 18 2023-04-19 08:30:14        None       None  utf8mb4_general_ci     None
# 19 2023-08-11 01:01:26        None       None  utf8mb4_0900_ai_ci     None
# 20 2023-08-11 01:07:58        None       None  utf8mb4_0900_ai_ci     None
# 21 2023-09-13 16:22:26        None       None  utf8mb4_unicode_ci     None
# 22 2023-09-21 16:29:55        None       None   latin1_swedish_ci     None
# 23 2023-04-19 08:30:55        None       None   latin1_swedish_ci     None
#
#         CREATE_OPTIONS TABLE_COMMENT
# 0   row_format=DYNAMIC
# 1
# 2   row_format=DYNAMIC
# 3
# 4   row_format=DYNAMIC
# 5
# 6
# 7
# 8
# 9
# 10  row_format=DYNAMIC
# 11  row_format=DYNAMIC
# 12
# 13
# 14
# 15
# 16
# 17
# 18  row_format=DYNAMIC
# 19
# 20
# 21
# 22
# 23
#
# [24 rows x 21 columns]

# %%
import nltk
#nltk.download('punkt')
nltk.download("popular")
#nltk.download("all")

#nltk.data.path.append('root/nltk_data/')
#nltk.download('wordnet')

# %%
# Data is downloaded to /root/nltk_data/corpora/comtrans.zip

from zipfile import ZipFile
file_loc = '/root/nltk_data/corpora/wordnet.zip'
with ZipFile(file_loc, 'r') as z:
  z.extractall('/root/nltk_data/corpora/')

# %%
from datetime import datetime
print ('Início - random_forest_final2_sbseg.py',datetime.now())
iopub_data_rate_limit=1.0e10
# Out:
# Início - random_forest_final2_sbseg.py 2023-09-26 01:46:42.086747

# %%
# !python random_forest_final2_sbseg.py
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print ('Fim - random_forest_final2_sbseg.py',datetime.now())
# Out:
# Fim - random_forest_final2_sbseg.py 2023-09-26 01:53:58.879610
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
