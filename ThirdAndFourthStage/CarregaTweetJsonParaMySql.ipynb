# %%
# !pip install pymysql
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\oi274676\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\oi274676\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\oi274676\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\oi274676\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\oi274676\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\oi274676\anaconda3\lib\site-packages)

# %%
from sqlalchemy import create_engine, text as sql_text
import pymysql
import pandas as pd

# %%
#Estrutura 'mysql+pymysql://user:password@ip/schema'
db_connection = 'mysql+pymysql://root:jef123*@localhost/ime'
engine = create_engine(db_connection)
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     843         try:
# --> 844             raise err
#     845         finally:
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     831                 sock.bind(source_address)
# --> 832             sock.connect(sa)
#     833             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# ...

# %%
#pd.read_sql ('show databases',conn)
query = sql_text('show databases')
pd.read_sql(query,conn)

# %%
import os

from twython import TwythonError, TwythonRateLimitError
from util.Constants import GET_USER, GET_USER_TWEETS, USER_ID, FOLLOWERS, GET_FRIENDS_ID, FOLLOWING
from util.TwythonConnector import TwythonConnector
from util.util import Config, is_folder_exists, create_dir, multiprocess_data_collection

from util.util import DataCollector

# %%
samples_folder= 'C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News/fake'

print(samples_folder)
# Out:
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News/fake

# %%
user_ids = set()

samples_folder= 'C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News/fake'
samples_folder= 'C:/Users/oi274676/OneDrive\Documentos\Python Scripts\FakeNewsSetGen-master\ThirdAndFourthStage\Dataset\News\fake
    
for news_id in os.listdir(samples_folder):
    print(news_id)
    news_dir = "{}/{}".format(samples_folder, news_id)
    print(news_dir)
    tweets_dir = "{}/{}/tweets".format(samples_folder, news_id)
    print(tweets_dir)
    
    if is_folder_exists(news_dir) and is_folder_exists(tweets_dir):

        for tweet_file in os.listdir(tweets_dir):
            tweet_object = json.load(open("{}/{}".format(tweets_dir, tweet_file)))
            print(tweet_file)
            print(tweet_object["user"]["id"])
            user_ids.add(tweet_object["user"]["id"])

return user_ids
# Out:
# 1025
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News/fake/1025
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News/fake/1025/tweets
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5108\682287178.py in <module>
#      13
#      14         for tweet_file in os.listdir(tweets_dir):
# ---> 15             tweet_object = json.load(open("{}/{}".format(tweets_dir, tweet_file)))
#      16             print(tweet_file)
#      17             print(tweet_object["user"]["id"])
#
# NameError: name 'json' is not defined
