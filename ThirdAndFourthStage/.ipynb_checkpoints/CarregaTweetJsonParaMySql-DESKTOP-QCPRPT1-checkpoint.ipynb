# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\utilizador\anaconda3\lib\site-packages (1.0.3)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilizador\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilizador\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilizador\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilizador\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilizador\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilizador\anaconda3\lib\site-packages)

# %%
from sqlalchemy import create_engine, text as sql_text
import pymysql
import pandas as pd

# %%
#Estrutura 'mysql+pymysql://user:password@ip/schema'
db_connection = 'mysql+pymysql://root:jef123*@localhost/ime'
engine = create_engine(db_connection)
conn = engine.connect()

# %%
#pd.read_sql ('show databases',conn)
query = sql_text('show databases')
pd.read_sql(query,conn)
# Out:
#              Database
# 0                 ime
# 1  information_schema
# 2               mysql
# 3           newschema
# 4  performance_schema
# 5                 sys

# %%
import json
import logging
import os
from pathlib import Path
from twython import TwythonError, TwythonRateLimitError

from util.Constants import GET_USER, GET_USER_TWEETS, USER_ID, FOLLOWERS, GET_FRIENDS_ID, FOLLOWING
from util.TwythonConnector import TwythonConnector
from util.util import Config, is_folder_exists, create_dir, multiprocess_data_collection

from util.util import DataCollector

from util.Constants import GET_FOLLOWERS_ID

from datetime import datetime

# %%
# Conexão com o banco de dados e crição de cursos
# algmas linhas comentadas são exemplos

import pymysql

#conectando ao banco de dados
db_connection = pymysql.connect(host = 'localhost', user = 'root', password = 'jef123*', db = 'ime',  autocommit=True)

#Criando objeto cursos
cursor_carrega_TweetsJsonToMySql = db_connection.cursor()   

# Montando SQL statements       
#sql_teste_tweets = queryInsert

#Execução da query 
#cursor_carrega_TweetsJsonToMySql.execute(sql_teste_tweets)
#result_tweets = cursor_carrega_TweetsJsonToMySql.fetchall()

# %%
# varre a pasta de tweets vinculados a notícias fakes e carrega a tabela content_polluters_tweets_original = TweetsOfLabeledNews
#user_ids = set()
ListOfTweets = set()

samples_folder= 'C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake'
queryInsert = ""

# Loop para varrer todas as pastas de notícias
for news_id in os.listdir(samples_folder):
    print(news_id)
    news_dir = "{}/{}".format(samples_folder, news_id)
    print(news_dir)
    tweets_dir = "{}/{}/tweets".format(samples_folder, news_id)
    print(tweets_dir)

    if is_folder_exists(news_dir) and is_folder_exists(tweets_dir):  
        vCount = 0
        #Loop que varre todos os arquivos jsons da pasta de notícias / tweets
        for tweet_file in os.listdir(tweets_dir):
            tweet_object = json.load(open("{}/{}".format(tweets_dir, tweet_file)))
            print(tweet_file)                      

            vUserId = tweet_object["user"]["id"]
            print(vUserId)
            
            #Id do Tweet, e só iremos armazenar uma única vez
            vTweetId = tweet_object["id"]
            print(vTweetId)
            
            if vTweetId in ListOfTweets :
                continue
            
            ListOfTweets.add(vTweetId)
            
            # Data de criação do Tweet
            vCreatedAT_Str = tweet_object["created_at"]   
            vCreatedAT = datetime.strptime(vCreatedAT_Str, "%a %b %d %H:%M:%S %z %Y")
            
            # Remover o fuso horário
            vCreatedAT_SemTimeZone = vCreatedAT.replace(tzinfo=None)
            
            # Converter de volta para uma string formatada
            vCreatedAT_Str = vCreatedAT_SemTimeZone.strftime("%Y-%m-%d %H:%M:%S")
            print(vCreatedAT_Str)

            vTweet = tweet_object["text"]            
            print(vTweet)
            
            vTweetTeste = repr(tweet_object["text"])
            print(vTweetTeste)
            
            vCount = vCount + 1
            print(vCount)

            #user_ids.add(tweet_object["user"]["id"])
            #queryInsert = queryInsert  + " INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (" + str(news_id) +", 1 ," + str(vUserId) +", " + str(vTweetId)+", '" +  str(vTweet) +"','"+  str(vCreatedAT_Str) +"'); \n\r"
            #queryInsert = "INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (" + str(news_id) +", 1 ," + str(vUserId) +", " + str(vTweetId)+", '" +  str(vTweet) +"','"+  str(vCreatedAT_Str) +"')"
            
            queryInsert = "INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s) " 
            print(queryInsert) 
            
            dados = ( str(news_id) , 1 , str(vUserId) ,  str(vTweetId) , str(vTweet) , str(vCreatedAT_Str) )
            #Execução da query 
            cursor_carrega_TweetsJsonToMySql.execute(queryInsert, dados)
        
#return user_ids
# Out:
# 1025
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/1025
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/1025/tweets
# 1628052888420335631.json
# 1478762410601328641
# 1628052888420335631
# 2023-02-21 15:23:51
# https://t.co/bmEV7hoD1U
#
# *⛔Juiz Sergio Moro manda Carta publica para o Povo Brasileiro*
#
# Para fazer "a revolução",… https://t.co/0O9HkofYYV
# 'https://t.co/bmEV7hoD1U\n\n*⛔Juiz Sergio Moro manda Carta publica para o Povo Brasileiro*\n\nPara fazer "a revolução",… https://t.co/0O9HkofYYV'
# 1
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1628198384052981763.json
# 2995798198
# 1628198384052981763
# 2023-02-22 01:01:59
# ⛔Juiz Sergio Moro manda Carta publica para o Povo Brasileiro🇧🇷
#
# Para fazer "a revolução", não precisamos pegar em a… https://t.co/ycsSNTtN3E
# '⛔Juiz Sergio Moro manda Carta publica para o Povo Brasileiro🇧🇷\n\nPara fazer "a revolução", não precisamos pegar em a… https://t.co/ycsSNTtN3E'
# 2
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1639978974120931330.json
# 2533500863
# 1639978974120931330
# 2023-03-26 13:13:51
# *Juiz Sergio Moro manda Carta publica para o Povo Brasileiro*Para fazer"a revolução"não precisamos pegar em armas o… https://t.co/QQZfUT4fDu
# '*Juiz Sergio Moro manda Carta publica para o Povo Brasileiro*Para fazer"a revolução"não precisamos pegar em armas o… https://t.co/QQZfUT4fDu'
# 3
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1049
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/1049
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/1049/tweets
# 1645218836839366657.json
# 4145136142
# 1645218836839366657
# 2023-04-10 00:15:12
# @RBolsonaro3 Notícia falsa
#
# https://t.co/6qNyCG38Fl
#
# https://t.co/Iqu900viqh
#
# https://t.co/rWSxZQxgMV
# '@RBolsonaro3 Notícia falsa \n\nhttps://t.co/6qNyCG38Fl\n\nhttps://t.co/Iqu900viqh\n\nhttps://t.co/rWSxZQxgMV'
# 1
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1099
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/1099
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/1099/tweets
# 1645218836839366657.json
# 4145136142
# 1645218836839366657
# 111
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/111
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/111/tweets
# 1625194523344179201.json
# 892454024619937793
# 1625194523344179201
# 2023-02-13 18:05:43
# @LuizCesar1957 @joel_fi @ggcramalho1 E os bolsonros que faziam churrasco com os assassinos da Mariele e outros milicianos...tá lembrado???
# '@LuizCesar1957 @joel_fi @ggcramalho1 E os bolsonros que faziam churrasco com os assassinos da Mariele e outros milicianos...tá lembrado???'
# 1
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 2003
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/2003
# C:/Users/utilizador/OneDrive/Documentos/Python Scripts/FakeNewsSetGen-master/ThirdAndFourthStage/Dataset/News_old/fake/2003/tweets
# 1624198054638153735.json
# 1241518025813229569
# 1624198054638153735
# 2023-02-11 00:06:07
# RT @OTioDoZAP: 🚨⚖️🤨🚩| O STF formou uma maioria para derrubar uma lei de Rondônia que proíbe o uso de linguagem neutra na grade curricular d…
# 'RT @OTioDoZAP: 🚨⚖️🤨🚩| O STF formou uma maioria para derrubar uma lei de Rondônia que proíbe o uso de linguagem neutra na grade curricular d…'
# 1
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1624203198733905924.json
# 91989624
# 1624203198733905924
# 2023-02-11 00:26:33
# RT @StaBeto: Em editorial, Estadão dispara críticas contra Alexandre de Moraes, do STF - Folha da Política https://t.co/liVZMV2vwY
# 'RT @StaBeto: Em editorial, Estadão dispara críticas contra Alexandre de Moraes, do STF - Folha da Política https://t.co/liVZMV2vwY'
# 2
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1624205352089657347.json
# 1484980376527331333
# 1624205352089657347
# 2023-02-11 00:35:06
# RT @PietraTito: o deputado americano, Clay Higgins adverte executivos do Twitter que eles podem ser presos por interferir nas eleições pres…
# 'RT @PietraTito: o deputado americano, Clay Higgins adverte executivos do Twitter que eles podem ser presos por interferir nas eleições pres…'
# 3
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1624210632315731973.json
# 1197983394958848000
# 1624210632315731973
# 2023-02-11 00:56:05
# RT @PauloCappelli_: O que Alexandre de Moraes pensa sobre punir Marcos do Val no STF https://t.co/gZSIK4dXDO
# 'RT @PauloCappelli_: O que Alexandre de Moraes pensa sobre punir Marcos do Val no STF https://t.co/gZSIK4dXDO'
# 4
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1624215537466081281.json
# 952979948934967297
# 1624215537466081281
# 2023-02-11 01:15:35
# RT @diariodopoder: Moraes autoriza a devolução dos celulares de Ibaneis Rocha e Valdemar Costa Neto: O ministro do Supremo Tribunal Federal…
# 'RT @diariodopoder: Moraes autoriza a devolução dos celulares de Ibaneis Rocha e Valdemar Costa Neto: O ministro do Supremo Tribunal Federal…'
# 5
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# 1624221825457684481.json
# 1575256838077128706
# 1624221825457684481
# 2023-02-11 01:40:34
# RT @Jolima0725: @robsonglopes45 @ACarlllos22 @SigaGazetaBR Eu Concordo Plenamente Com vc.
# foram Alexandre de Moraes foram Lula foram Barros…
# 'RT @Jolima0725: @robsonglopes45 @ACarlllos22 @SigaGazetaBR Eu Concordo Plenamente Com vc.\nforam Alexandre de Moraes foram Lula foram Barros…'
# 6
# INSERT INTO ime.tweetsoflabelednews (LabeledNewsId, FakeNews, UserID, TweetID, Tweet, CreatedAt) VALUES (%s, %s, %s, %s, %s, %s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1508\2688852125.py in <module>
#      18         #Loop que varre todos os arquivos jsons da pasta de notícias / tweets
#      19         for tweet_file in os.listdir(tweets_dir):
# ---> 20             tweet_object = json.load(open("{}/{}".format(tweets_dir, tweet_file)))
#      21             print(tweet_file)
#      22
#
# ~\anaconda3\lib\_bootlocale.py in getpreferredencoding(do_setlocale)
#       9
#      10 if sys.platform.startswith("win"):
# ---> 11     def getpreferredencoding(do_setlocale=True):
#      12         if sys.flags.utf8_mode:
#      13             return 'UTF-8'
#
# KeyboardInterrupt:
